# %% [markdown]
# # Traffic Light Classifier

# %% [markdown]
# # 1. Loading and Visualizing the Traffic Light Dataset

# %%
import helpers
import functions

# %matplotlib inline

# %% [markdown]
#    ### -          Create image path

# %%
# create image path
IMAGE_DIR_TRAINING = "traffic_light_images/training/"
IMAGE_DIR_TEST = "traffic_light_images/test/"

# %%
# Load training data:
    # each image is a tuple: (image matrix, numeric lable, string label)
    # numberic labels with their corresponding string labels:
    # red [1,0,0], yellow [0,1,0],green [0,0,1]
IMAGE_LIST = helpers.load_dataset(IMAGE_DIR_TRAINING)

# %%
# show one single image with its label
functions.show_single_rgb_image(IMAGE_LIST[0])

# %% [markdown]
#  # 2. Pre-process the Data

# %% [markdown]
# #### - Pre-Processing includes two functions:
#     - unify_image_size: square and resize a single image (32 x 32 pixels)
#     - standardize all images

# %%
image_size = 32 # make images 32 x 32 pixel
STD_LIST = functions.standardize(IMAGE_LIST, image_size)

# %%
# visualize random images
images_to_compare = [2, 724, 800]       
functions.visualize_std_vs_original_images(IMAGE_LIST, STD_LIST, images_to_compare)

# %%
a = [1,2,3,4,5,67]
label = [str(x) for x in a]
label += "hello"
print(label)
# Out:
# ['1', '2', '3', '4', '5', '67', 'h', 'e', 'l', 'l', 'o']

# %% [markdown]
# # 3. Feature Extraction

# %% [markdown]
# # 4. Classify and Determine Accuracy of the model

# %% [markdown]
# # 5. Improve the algorithm.
